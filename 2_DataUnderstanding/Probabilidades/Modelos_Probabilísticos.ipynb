# %% [markdown]
# http://www.leg.ufpr.br/~fernandomayer/aulas/ce083-2015-02/ce083_aula7_2015-02.html#Distribui__o_de_Poisson
#
# https://bookdown.org/matheusogonzaga/apostila_r2/distribuicoes-de-probabilidade.html#poisson
#
# https://www.inf.ufsc.br/~andre.zibetti/probabilidade/index.html

# %% [markdown]
# Um dos objetivos da Estatística é fazer inferência (ou tirar conclusões) sobre distribuições de variáveis em populações a partir de dados de uma parte dela,denominada amostra. A ligação entre os dados amostrais e a população depende de modelos probabilísticos ou seja, de modelos que representem a distribuição (desconhecida) da variável na população.
#
# Não se pode obter a correspondente distribuição de frequências de alguma característica de interesse associada a essa população e o recurso a modelos para essa distribuição faz-se necessário; esses são os chamados modelos probabilísticos e as frequências relativas correspondentes são denominadas probabilidades.
#
# Se pudermos supor que a distribuição de probabilidades de uma variável
# X, definida sobre uma população possa ser descrita por um determinado
# modelo probabilístico representado por uma função, nosso problema reduzisse a estimar os parâmetros que a caracterizam
#
# Os modelos probabilísticos possuem:
#
#
#
# 1.  *A função de probabilidade p(x) = P(X = x), no caso discreto e a função densidade de probabilidade, f(x), no caso contínuo;*
# 2.  *Os parâmetros que caracterizam cada distribuição;*
# 3.  *O valor esperado, representado por E(X) e a variância, representada por Var(X) de cada uma delas.*

# %% [markdown]
# #1. Variáveis Discretas

# %% [markdown]
# ![var_disc.PNG](data:image/png;base64,...)

# %% [markdown]
# ##1.1 Bernoulli

# %% [markdown]
# A distribuição de Bernoulli se trata de um experimento que resulta em sucesso ou fracasso. O modelo Binomial se trata de vários experimentos de Bernoulli. Uma distribuição binomial com parâmetro n = 1 é equivalente a uma distribuição de Bernoulli

# %% [markdown]
# ##1.2 Binomial

# %% [markdown]
# Um dos principais modelos discretos de probabilidade é o modelo Binomial. Quando possuímos uma sequência de n experimentos independentes entre si,com variáveis binárias como resposta (sucesso ou fracasso), dada uma determinada probabilidade constante de sucesso, podemos obter a probabilidade de ocorrência de k sucessos através da distribuição binomial.
#
# ![image.png](data:image/png;base64,...)

# %%
dbinom(x, size, prob) #calculo de probabilidades
pbinom(q, size, prob) #probabilidade acumulada
qbinom(p, size, prob) #quantis da distribuicao
rbinom(n, size, prob) #experimentos

# quando P(x<= N) = lower.tail = TRUE
# quando P(x>8) = lower.tail = FALSE
# o comando lower.tail vale para todas as distribuições
# Out:
# [1] "Binomial"

# %% [markdown]
# --------------------------

# %% [markdown]
# **Exemplo:**
#
# *Determinada peça é produzida em uma linha de produção.A probabilidade de que a peça não tenha defeitos
# é de 99%. Se forem produzidas 30 peças, qual a probabilidade de que pelo menos 28 delas esteja em boas condições?*

# %%
dbinom(28, 30, 0.99) + dbinom(29, 30, 0.99) + dbinom(30, 30, 0.99)
# Out:
# [1] 0.9966823

# %% [markdown]
# ---------------------

# %% [markdown]
# ##1.3 Poisson

# %% [markdown]
# A distribuição Poisson é utilizada para registrar a ocorrência de eventos raros, com probabilidade de sucesso
# muito pequena (p -> O), em determinada exposição (por exemplo, em determinado intervalo de tempo ou espaço).
#
# Diferentemente do modelo binomial, que fornece a probabilidade do número de sucessos em um intervalo
# discreto (n repetições de um experimento), o modelo Poisson fornece a probabilidade do número de sucessos
# em determinado intervalo contínuo (tempo, área, entre outras possibilidades de exposição). Como exemplos de
# variáveis que representam a distribuição Poisson, podemos mencionar a quantidade de clientes que chegam à
# fila por unidade de tempo, a quantidade de defeitos por fábrica, a quantidade de acidentes por município, etc.
# Podemos notar que as unidades de medida de exposição (tempo, unidade fabril e município, nessas situações) são
# contínuas, mas a variável aleatória (número de ocorrências) é discreta.
#
# A distribuição Poisson apresenta as seguintes hipóteses:
#
# (i) Eventos definidos em intervalos não sobrepostos são independentes;
#
# (ii) Em intervalos de mesmo comprimento, as probabilidades de ocorrência de um mesmo número de sucessos são iguais;
#
# (iii) Em intervalos muito pequenos, a probabilidade de ocorrência de mais de um sucesso é desprezível;
#
# (iv) Em intervalos muito pequenos, a probabilidade de um sucesso é proporcional ao comprimento do intervalo.
#
# ![image.png](data:image/png;base64,...)

# %%
dpois(x, lambda, log = FALSE) # probabilidade associada a um valor de X
ppois(q, lambda, lower.tail = TRUE, log.p = FALSE) # valor da prababilidade acumulada avaliada em um X qualquer
qpois(p, lambda, lower.tail = TRUE, log.p = FALSE) # descobrir os quantis da distribuição Poisson
rpois(n, lambda)
# Out:
# [1] "Poisson"

# %% [markdown]
# ---------------------------

# %% [markdown]
# **Exemplo:**
#
# *Suponha que o número de clientes que chegam a um banco siga uma distribuição Poisson.Verifica-se que, em
# média, chegam 12 clientes por minuto. Calcule:*
#
# *a) probabilidade de chegada de 10 clientes no próximo minuto;*
#
# *b) probabilidade de chegada de 40 clientes nos próximos 5 minutos;*

# %%
#a)
dpois(10, 12)

#b) #40/5 --> 8 clientes por minuto
dpois(8,12)
# Out:
# [1] 0.1048373
# [1] 0.06552328

# %% [markdown]
# --------------------------------------

# %% [markdown]
# ##1.4 Geométrica

# %% [markdown]
# A distribuição geométrica, assim como a binomial, considera sucessivos ensaios de Bernoulli independentes, todos com probabilidade de sucesso p. Porém, em vez de utilizar um número fixo de tentativas, elas serão realizadas até que o primeiro sucesso seja obtido
#
# ![image.png](data:image/png;base64,...)

# %%
dgeom(x, prob, log = FALSE)
pgeom(q, prob, lower.tail = TRUE, log.p = FALSE)
qgeom(p, prob, lower.tail = TRUE, log.p = FALSE)
rgeom(n, prob)

# %% [markdown]
# -----------------------------

# %% [markdown]
# **Exemplo**
#
# *Uma empresa fabrica determinado componente eletrônico, de modo que, ao final do processo, cada componente é testado, um a um. Suponha que a probabilidade de um componente eletrônico estar defeituoso seja
# de 0,05. Determine a probabilidade de que o primeiro defeito seja encontrado no oitavo componente testado.*

# %%
dgeom(8, 0.05)
# Out:
# [1] 0.03317102

# %% [markdown]
# --------------------

# %% [markdown]
# ##1.5 Hipergeométrica

# %% [markdown]
# A distribuição hipergeométrica também está relacionada com um experimento de Bernoulli. Porém, diferentemente da amostragem binomial, em que a probabilidade de sucesso é constante, na distribuição hipergeométrica, como a amostragem é sem reposição, à medida que os elementos são retirados da população para formar aamostra, o tamanho da população diminui, fazendo com que a probabilidade de sucesso varie.
#
#
# A distribuição hipergeométrica descreve o número de sucessos na amostra de n elementos, extraída de uma
# população finita sem reposição. Por exemplo, consideremos uma população com N elementos, dos quais M possuem determinado atributo. A distribuição hipergeométrica descreve a probabilidade de que, em uma amostra
# com n elementos distintos extraídos aleatoriamente da população sem reposição, exatamente k possuem tal atributo (k sucessos e n - k fracassos).
#
# ![image.png](data:image/png;base64,...)

# %%
dhyper(x, m, n, k, log = FALSE)
phyper(q, m, n, k, lower.tail = TRUE, log.p = FALSE)
qhyper(p, m, n, k, lower.tail = TRUE, log.p = FALSE)
rhyper(nn, m, n, k)
# Out:
# [1] "Hipergeometrica"

# %% [markdown]
# --------------------

# %% [markdown]
# **Exemplo**
#
# *Uma urna contém 15 bolas, das quais 5 delas são vermelhas. São escolhidas 7 bolas ao acaso, sem reposição.
# Determine:*
#
# *a)  A probabilidade de que exatamente duas bolas vermelhas sejam sorteadas.*
#
# *b)  A probabilidade de que pelo menos duas bolas vermelhas sejam sorteadas.*

# %%
#a
dhyper(2,5,10,7)

#b
# P(x>=2) --> 1 - P(x<2) --> 1 - P(x=0) + P(x=1)
1 - ((dhyper(0,5,10,7)) + dhyper(1,5,10,7))
# Out:
# [1] 0.3916084
# [1] 0.8181818

# %% [markdown]
# ------------

# %% [markdown]
# #2. Variáveis Contínuas

# %% [markdown]
# ![var_cont.PNG](data:image/png;base64,...)

# %% [markdown]
# ##2.2 Normal

# %% [markdown]
# A distribuição normal, também conhecida como distribuição Gaussiana, é a distribuição de probabilidade mais utilizada e importante, pois permite modelar uma infinidade de fenômenos naturais, estudos do comportamento humano, processos industriais, entre outros, além de possibilitar o uso de aproximações para o cálculo
# de probabilidades de muitas variáveis aleatórias

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dnorm(x, mean = 0, sd = 1, log = FALSE)
pnorm(q, mean = 0, sd = 1, lower.tail = TRUE, log.p = FALSE)
qnorm(p, mean = 0, sd = 1, lower.tail = TRUE, log.p = FALSE)
rnorm(n, mean = 0, sd = 1)
# Out:
# [1] "Normal"

# %% [markdown]
# --------------

# %% [markdown]
# **Exemplo**
#
# *Sabe-se que a espessura média dos abrigos para mangueira produzidos em uma fábrica (X) segue uma distribuição normal com média 3 mm e desvio-padrão 0,4 mm. Determine:*
#
# *a) P(X > 4,1)*
#
# *b)P(X>3)*
#
# *c) P(X<=3)*
#
# *d) P(X<=3,5)*
#
# *e) P(X < 2,3)*
#
# *f) P(2 <= X <= 3,8)*

# %%
#a)
pnorm(4.1, mean = 3, sd = 0.4, lower.tail = FALSE)

#b)
pnorm(3,3,0.4)

#c)
pnorm(3, 3, 0.4, lower.tail = TRUE)

#d)
pnorm(3.5,3,0.4, lower.tail = TRUE)

#e)
# e) 1 - P(x>=2,3)
1 - pnorm(2.3,3,0.4, lower.tail = FALSE)

#f)
#f) [ P(x<2) + P(x>3,8) ] - 1
((1 - pnorm(2,3,0.4,lower.tail = TRUE)) + pnorm(3.8,3,0.4)) - 1
# Out:
# [1] 0.002979763
# [1] 0.5
# [1] 0.5
# [1] 0.8943502
# [1] 0.04005916
# [1] 0.9710402

# %% [markdown]
# ------------------
